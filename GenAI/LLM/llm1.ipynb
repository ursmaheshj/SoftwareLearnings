# %%
from google import genai

# %%
client = genai.Client(api_key="AIzaSyBMF7-vVs1TZ--ZgrFB4MEc-Eh7yD05YaE")

# %%
response = client.models.generate_content(
    model="gemini-3-flash-preview", 
    contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI works by **finding patterns in data** to make predictions or decisions.

# %%
response = client.models.generate_content(
    model="gemini-3-flash-preview", 
    contents="I am mahesh"
)
print(response.text)
# Out:
# Hello Mahesh! It's nice to meet you. How can I help you today?

# %%
response = client.models.generate_content(
    model="gemini-3-flash-preview", 
    contents="What is my name"
)
print(response.text)
# Out:
# I don’t know your name yet! As an AI, I don’t have access to your personal information or identity unless you share it with me in our conversation.
#
# What would you like me to call you?

# %%
# gemini-2.5-flash-lite
response = client.models.generate_content(
    model="gemini-2.5-flash-lite", 
    contents="you can call me mahesh"
)
print(response.text)
# Out:
# Okay, Mahesh! It's nice to meet you. How can I help you today?
